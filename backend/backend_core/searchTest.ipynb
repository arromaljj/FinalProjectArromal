# %%
import search

# %%
s = search.Search("Computer", getResult=False)
res = s.test_search()
res.content
# Out:
# b'{"query": "Computer", "number_of_results": 0, "results": [], "answers": [], "corrections": [], "infoboxes": [], "suggestions": [], "unresponsive_engines": [["duckduckgo", "timeout"], ["google", "timeout"], ["qwant", "timeout"], ["wikidata", "timeout"], ["wikipedia", "timeout"]]}'

# %%
s = search.Search("Computer")
s.result
# Out:
# {'results': [{'url': 'https://en.wikipedia.org/wiki/Computer',
#    'title': 'Computer',
#    'content': 'A computer is a digital electronic machine that can be programmed to carry out sequences of arithmetic or logical operations (computation) automatically.Modern computers can perform generic sets of operations known as programs.These programs enable computers to perform a wide range of tasks. A computer system is a "complete" computer that includes the hardware, operating system (main software ...',
#    'category': 'general'},
#   {'url': 'https://edu.gcfglobal.org/en/computerbasics/what-is-a-computer/1/',
#    'title': 'Computer Basics: What is a Computer? - GCFGlobal',
# ...

# %%
search.Search("asdf").html().content
# Out:
# b'<!DOCTYPE html>\n<html class="no-js theme-auto center-aligment-no" lang="en-EN" >\n<head>\n  <meta charset="UTF-8" />\n  <meta name="description" content="SearXNG \xe2\x80\x94 a privacy-respecting, hackable metasearch engine">\n  <meta name="keywords" content="SearXNG, search, search engine, metasearch, meta search">\n  <meta name="generator" content="searxng/2022.09.09-eb3d185e">\n  <meta name="referrer" content="no-referrer">\n  <meta name="robots" content="noarchive">\n  <meta name="viewport" content="width=device-width, initial-scale=1">\n  <meta name="HandheldFriendly" content="True">\n  <meta http-equiv="X-UA-Compatible" content="IE=edge, chrome=1">\n  <title>my-instance</title>\n<link rel="alternate" type="application/rss+xml" title="Searx search: asdf" href="http://localhost:8080/search?q=asdf&amp;categories=general&amp;pageno=1&amp;time_range=None&amp;language=en&amp;safesearch=0&amp;format=rss">  <link rel="stylesheet" href="/static/themes/simple/css/searxng.min.css" type
# ...
